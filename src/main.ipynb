# %% [markdown]
# # These tasks will focus on software engineering in ***Python***, ***pandas***, ***data manipulation*** and ***testing***. The challenge will be solved in a pair programming modality where you will be the driver (i.e. the person coding) and the interviewer will be the navigator (i.e. the person helping you code).

# %% [markdown]
# ## Pandas

# %%
import pandas as pd
import numpy as np
import logging

# %%
logging.basicConfig(
    filename='main.ipynb.log', 
    level=logging.INFO, 
    format="%(asctime)s [%(levelname)8s] %(message)s (%(filename)s:%(lineno)s)")
logger = logging.getLogger(__name__)

# %%
filename = "../data/comic_books_10000_dataset.csv"

# %%
comic_book_df = pd.read_csv(filename)

# %%
comic_book_df.head()
# Out:
#     comic_id               Title           Writer          Artist  \
# 0  CMC-00001       Tiger of Zero   Gintoki Sakata  Gintoki Sakata
# 1  CMC-00002        Twisted Claw   Fumi Takahashi     Mika Sasaki
# 2  CMC-00003  Jean Grey: Rebirth     Chip Zdarsky          Bendis
# 3  CMC-00004       Abyss Destiny   Yuna Yamaguchi  Yuna Yamaguchi
# 4  CMC-00005         After Smoke  Shannon Watters    Warren Ellis
#
#           Studio/Publisher  Release Year         Format  \
# 0   Shogakukan (Viz Media)          2001       Tankobon
# 1   Shogakukan (Viz Media)          2015       Tankobon
# 2            Marvel Comics          2016  Graphic Novel
# 3  Kodansha (Kodansha USA)          2014   Manga Volume
# 4          Kodansha Comics          2005            OGN
#
#             Theme (Color Style)                  Genre Country of Origin  \
# 0  Full Color (Special Edition)       Shoujo / Romance             Japan
# 1                 Black & White    Action / Historical             Japan
# ...

# %%
comic_book_df.loc[comic_book_df.isna().any(axis=1)]
# Out:
#        comic_id                           Title            Writer  \
# 0     CMC-00001                   Tiger of Zero    Gintoki Sakata
# 1     CMC-00002                    Twisted Claw    Fumi Takahashi
# 4     CMC-00005                     After Smoke   Shannon Watters
# 6     CMC-00007                       Ancient X  Kazushi Hagiwara
# 8     CMC-00009                        Day Fang    Akira Toriyama
# ...         ...                             ...               ...
# 9995  CMC-09996          Forsaken Reincarnation       Kai Yoshida
# 9996  CMC-09997                     Lion Memory      Daisuke Imai
# 9997  CMC-09998  Legendary F-Ranked Void System      Nam Hyun-jun
# 9998  CMC-09999                   The Lost Gold  Noelle Stevenson
# 9999  CMC-10000                      Hero Tower           Jung Ha
#
#                 Artist         Studio/Publisher  Release Year  \
# 0       Gintoki Sakata   Shogakukan (Viz Media)          2001
# ...

# %%
comic_book_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   comic_id             10000 non-null  str
#  1   Title                10000 non-null  str
#  2   Writer               10000 non-null  str
#  3   Artist               10000 non-null  str
#  4   Studio/Publisher     10000 non-null  str
#  5   Release Year         10000 non-null  int64
#  6   Format               10000 non-null  str
#  7   Theme (Color Style)  10000 non-null  str
#  8   Genre                10000 non-null  str
#  9   Country of Origin    10000 non-null  str
#  10  Page Count           10000 non-null  int64
#  11  Rating (out of 10)   10000 non-null  float64
#  12  Status               10000 non-null  str
#  13  Language             10000 non-null  str
#  14  Age Rating           10000 non-null  str
#  15  Awards               3984 non-null   str
# ...

# %%
null_count_by_col = {col: int(np.count_nonzero(comic_book_df[col].isna())) for col in comic_book_df.columns}
logger.info(f"Dataset directory: {filename}, null count by column: {null_count_by_col} with {len(comic_book_df)} rows")
